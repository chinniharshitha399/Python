# %% [markdown]
#  # Tuples :
#   Tuples are similar to lists but they are immutable, i.e. they cannot be changed. You would use the tuples to present data that shouldn't be changed, such as days of the week or dates on  a calendar. It is a collection of both homogeneous and heterogeneous values enclosed in ( )
#
# -It is indexed, and it also allows duplicate values
#
# Syntax: var= (val1, val2, val3,....valn) or var= val1
#
# ex: a= (2+3j, 24, (10,20,'python'), 3.12)
#
# indexing: value space                             variable space
#
#            a 0*11                                  (2+3j, 24, (10,20,'python'), 3.12) (0,1,2 (0*12),3)
#
#                                                     (10,20,'python'(0*13)) (0,1,(0*12))
#
#                                                      (p,y,t,h,o,n) (0,1,2,3,4,5)

# %%
*len(): to find length of above variable
 syntax: var[index]

ex: print(len(a))    #4

print(len(a[2]))       #3

# %%
ex:  a = ('ram',2.3, 'python', 18)
print(a[1])      # indexing         #[2.3]
print(a[1:3])    # slicing   #[2.3,'python']
print(a[::-1])   # reverse     # [18, 'python', 2.3, 'ram']

# %%
ex: Calculate Total and Average marks  Using Tuple
marks = (85, 90, 78, 92, 88)
# Calculate total
total = 0
for m in marks:
    total += m
    
# Calculate average
average = total / len(marks)
# Print results
print("Marks:", marks)
print("Total:", total)
print("Average:", average)

## Immutability (cannot modify)
marks[2] = 48       # ❌ Error

# %%
# Sets:
-Sets are an unordered collection of *unique* elements which can be constructed using the set{} function.

-Duplicate values are not allowed

-sets are mutable (can add/remove items), but their elements must be immutable.

-all single value datatypes are immutable. Vaules must be immutable datatype.

**Allowed elements** (immutable):int, float, complex

string

tuple (if it contains only immutable items)

**Not allowed** (mutable):list ,dict, set

-Use set() for empty set ( {} makes an empty dict )
Or use {1,2,3} for non-empty set

# %%
# add()
a = set()
a.add(3)
a.add(2)
a.add(3)  # duplicate, will not be added again
a

#Sets remove duplicates automatically
a={},

# %%
a = [1, 3, 3, 2, 5, 6, 6, 7, 8, 2, 3, 5, 6, 2, 5]
a_set = set(a)
a_set
# Remove
a_set.remove(8);
a_set
# Out:
# {1, 2, 3, 5, 6, 7}

# %%
Safe removal: discard() vs remove()
discard(x) does nothing if x not present
remove(x) raises KeyError if x not present

# %%
s = {1, 2, 3, 5, 6, 7}
removed = s.pop()
print("Removed by pop():", removed)
print("Now:", s)

s.clear()
print("After clear():", s)

# %% [markdown]
# Dictionaries: A dictionary (dict) stores data as key → value pairs.
#
#  Key properties:
#
# Keys must be unique
# Keys must be hashable (immutable types like str, int, tuple)
# Values can be anything (numbers, lists, dicts, objects)
#
# ## METHODS:
# clear()	Removes all the elements from the dictionary
# copy()	Returns a copy of the dictionary
# pop()	Removes the element with the specified key
# update()	Updates the dictionary with the specified key-value pairs
# values()	Returns a list of all the values in the dictionary
# keys()	Returns a list containing the dictionary's keys
# items()	Returns a list containing a tuple for each key value pair

# %%
d = {"key1": 1, "key2": 2, "key3": 3}

print("keys:", list(d.keys()))
print("values:", list(d.values()))
print("items:", list(d.items()))

# %% [markdown]
#  # Shallow Copy vs Deep Copy:
# -shallow copy creates a new dictionary but does NOT copy inner objects completely.
# -Inner objects are still shared between original and copied dictionary.

# %%
import copy

original = {"a": 1, "b": [10, 20]}
shallow = copy.copy(original)

shallow["b"][0] = 99

print(original)

# %% [markdown]
# # Deep Copy
# deep copy creates a completely independent copy.

# %%
import copy

original = {"a": 1, "b": [10, 20]}
deep = copy.deepcopy(original)

deep["b"][0] = 99

print(original)
